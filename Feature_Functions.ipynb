# %% [markdown]
# # Functions for user inputs

# %%
import pandas as pd
import Functions_Books as funct
from fuzzywuzzy import process
# Out:
# c:\users\anton\appdata\local\programs\python\python39\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df1=pd.read_csv('DataFinal\DataPreprocessed.csv',index_col=0)
df1.reset_index(drop=True)
# Out:
#                                                   title  \
# 0                                  Mistress Suffragette
# 1                            Stones (One True Child #5)
# 2                                      Mission: Subhero
# 3     A Summer of Good-Byes (Blue Triangle Press Boo...
# 4                                     The Scopas Factor
# ...                                                 ...
# 8132                                   The Stove-Junker
# 8133                                     The Treemakers
# 8134        100 Years: A Journey to End a Vicious Cycle
# 8135    Thrive: 30 Inspirational Rags-to-Riches Stories
# 8136                                  The Smoke at Dawn
#
#                                         series               authors  \
# 0                                         none        Diana   Forbes
# 1                                         none             L.C. Conn
# 2                                         none    Linda    Armstrong
# ...

# %% [markdown]
# ## Year

# %%
df1['year'].dtype
# Out:
# dtype('O')

# %%
#funct.convert_data_types(df,'date', incolumns=['year'])

# %%
df[df['year']=='None']
# Out:
#                                                   title series  \
# 925                                 The Brothers Silver   none
# 1658                          Stepping Beyond Intention   none
# 3011  Mourning Grey: Part Three The Guardians Of The...   none
# 3377                                          Euthyphro   none
# 3644                               Night That Jimi Died   none
# ...                                                 ...    ...
# 8143                             Over The Rainbow I Fly   none
# 8224                                   Eclavarda Rising   none
# 8278                          The Travels of Marco Polo   none
# 8285                                          witchbird   none
# 8354                           Asleep with One Eye Open   none
#
#                        authors           isbn  \
# 925               Marc Jampole              0
# 1658            Daniel Mangena     1999957113
# 3011             Marie Montine              0
# ...

# %% [markdown]
# 83 books with no year. Those could not be found in sidebar..

# %%
xd1 = df['year'].value_counts()
xd1
# Out:
# 2013    555
# 2012    552
# 2014    520
# 2011    433
# 2015    290
#        ...
# 1517      1
# 1726      1
# 1516      1
# 1766      1
# 1782      1
# Name: year, Length: 313, dtype: int64

# %% [markdown]
# ## Pages # Maximum number of pages

# %%
xd = df['pages'].sort_values(ascending=True)
xd
# Out:
# 2490        0
# 6982        0
# 7433        0
# 7637        0
# 2727        0
#         ...
# 5449     4000
# 1075     4081
# 986      4211
# 2688     5216
# 7078    27500
# Name: pages, Length: 8139, dtype: int64

# %%
def select_pages(pages):
    try:
        df = df1[df1['pages']<=int(pages)]
        return df
    except: 
        return df1

# %%
select_pages('')
# Out:
#                                                   title  \
# 0                                  Mistress Suffragette
# 1                            Stones (One True Child #5)
# 2                                      Mission: Subhero
# 3     A Summer of Good-Byes (Blue Triangle Press Boo...
# 4                                     The Scopas Factor
# ...                                                 ...
# 8132                                   The Stove-Junker
# 8133                                     The Treemakers
# 8134        100 Years: A Journey to End a Vicious Cycle
# 8135    Thrive: 30 Inspirational Rags-to-Riches Stories
# 8136                                  The Smoke at Dawn
#
#                                         series               authors  \
# 0                                         none        Diana   Forbes
# 1                                         none             L.C. Conn
# 2                                         none    Linda    Armstrong
# ...

# %% [markdown]
# ## Ratings

# %%
def select_rating(rating):
    try:
        min_rating = rating[0]
        max_rating = rating[1]
        df = df1[df1['average_rating'].between(min_rating, max_rating)]
        return df
    except:
        return df1

# %%
select_rating((4.0,5.0))
# Out:
#                                                   title  \
# 0                                  Mistress Suffragette
# 1                            Stones (One True Child #5)
# 2                                      Mission: Subhero
# 3     A Summer of Good-Byes (Blue Triangle Press Boo...
# 4                                     The Scopas Factor
# ...                                                 ...
# 8127                               The Elemental Master
# 8128                                     Innocent Blood
# 8133                                     The Treemakers
# 8134        100 Years: A Journey to End a Vicious Cycle
# 8136                                  The Smoke at Dawn
#
#                                         series               authors  \
# 0                                         none        Diana   Forbes
# 1                                         none             L.C. Conn
# 2                                         none    Linda    Armstrong
# ...

# %% [markdown]
# ## No of ratings

# %%
def select_no_ratings(no_ratings):
    try:
        df = df1[df1['total_number_ratings']>=int(no_ratings)]
        return df
    except: 
        return df1

# %%
def select_no_ratings(no_ratings):
    if no_ratings >0 & no_ratings <12000000:
        df1 = df1[df1['total_number_ratings']>=int(no_ratings)]
        return df1
    elif no_ratings == '':
        return df1
    else:
        return df1

# %%
select_no_ratings(60)
# Out:
#                                                   title  \
# 0                                  Mistress Suffragette
# 1                            Stones (One True Child #5)
# 2                                      Mission: Subhero
# 3     A Summer of Good-Byes (Blue Triangle Press Boo...
# 4                                     The Scopas Factor
# ...                                                 ...
# 8129                           A Few Right Thinking Men
# 8130                     The Testament of Vida Tremayne
# 8133                                     The Treemakers
# 8135    Thrive: 30 Inspirational Rags-to-Riches Stories
# 8136                                  The Smoke at Dawn
#
#                                         series               authors  \
# 0                                         none        Diana   Forbes
# 1                                         none             L.C. Conn
# 2                                         none    Linda    Armstrong
# ...

# %% [markdown]
# ## Combine 2.- 4.

# %%
if st.button('Select'):
    
    #Subset according to max page number
    if 
    try:
        df = df1[df1['pages']<=int(pages)]
    except: 
        df1=pd.read_csv('DataFinal\DataPreprocessed.csv',index_col=0)
            
        #outcome dataframe

# %%
pages = 40
print(isinstance(pages, int))
# Out:
# True

# %%
def functionallfeatures(pages,rating,no_ratings):
    dfo=pd.read_csv('DataFinal\DataPreprocessed.csv',index_col=0)
    #reset index
    dfo.reset_index(drop=True, inplace=True)
    #1. Check user input: rating
    min_rating = rating[0]
    max_rating = rating[1]
    #df = df1[df1['average_rating'].between(min_rating, max_rating)]
    #2. Check user input: page number
    if isinstance(pages, int) is True: #pages True,av_rating=True immer, no_ratinsg True/False
        df = dfo[dfo['pages']<=int(pages)]
        df2 = df[df['average_rating'].between(min_rating, max_rating)]
        if isinstance(no_ratings, int) is True:
            df1 = df2[df2['total_number_ratings']>=int(no_ratings)]
        else:
            df1=df2.copy()    
    else: #Pages False(nicht gefiltert),av_rating True immer, rating True/False
        df3 = dfo[dfo['average_rating'].between(min_rating, max_rating)]
        if isinstance(no_ratings, int) is True:
            df1 = df3[df3['total_number_ratings']>=int(no_ratings)]
        else:
            df1=df3.copy()
    return df1

# %%
functionall(100000,(4.0,5.0),0)
# Out:
#                                                   title  \
# 0                                  Mistress Suffragette
# 1                            Stones (One True Child #5)
# 2                                      Mission: Subhero
# 3     A Summer of Good-Byes (Blue Triangle Press Boo...
# 4                                     The Scopas Factor
# ...                                                 ...
# 8127                               The Elemental Master
# 8128                                     Innocent Blood
# 8133                                     The Treemakers
# 8134        100 Years: A Journey to End a Vicious Cycle
# 8136                                  The Smoke at Dawn
#
#                                         series               authors  \
# 0                                         none        Diana   Forbes
# 1                                         none             L.C. Conn
# 2                                         none    Linda    Armstrong
# ...

# %% [markdown]
# ## Genres #FuzzyWuzzy oder select -> all rows that include those

# %%
#need to do explode on genres 
# if selected genres is in column/row/cells
def find_genres(genres):
    list=[]
    for i in genres:
        data = df[df['genres'].str.match(genres)]
    return data

# %% [markdown]
# ## Authors

# %%
#Sidebar:Authors(fuzzy), ifnot empty, else: continue
#minimum number of total ratings 1 way slider (if column. row min(ratingsinput), subset )
#Rating 2 way slider
#pages max number of pages
