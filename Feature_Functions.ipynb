# %% [markdown]
# # Functions for user inputs

# %%
import pandas as pd
import Functions_Books as funct

# %%
df = pd.read_csv('DataFinal\Datatotestmodel.csv', index_col=0)
df.reset_index(drop=True)
# Out:
#                                                   title  \
# 0                                  Mistress Suffragette
# 1                            Stones (One True Child #5)
# 2                                      Mission: Subhero
# 3     A Summer of Good-Byes (Blue Triangle Press Boo...
# 4                                     The Scopas Factor
# ...                                                 ...
# 8134                                   The Stove-Junker
# 8135                                     The Treemakers
# 8136        100 Years: A Journey to End a Vicious Cycle
# 8137    Thrive: 30 Inspirational Rags-to-Riches Stories
# 8138                                  The Smoke at Dawn
#
#                                         series               authors  \
# 0                                         none        Diana   Forbes
# 1                                         none             L.C. Conn
# 2                                         none    Linda    Armstrong
# ...

# %% [markdown]
# ## Year

# %%
df['year'].dtype
# Out:
# dtype('O')

# %%
#funct.convert_data_types(df,'date', incolumns=['year'])

# %%
df[df['year']=='None']
# Out:
#                                                   title series  \
# 925                                 The Brothers Silver   none
# 1658                          Stepping Beyond Intention   none
# 3011  Mourning Grey: Part Three The Guardians Of The...   none
# 3377                                          Euthyphro   none
# 3644                               Night That Jimi Died   none
# ...                                                 ...    ...
# 8143                             Over The Rainbow I Fly   none
# 8224                                   Eclavarda Rising   none
# 8278                          The Travels of Marco Polo   none
# 8285                                          witchbird   none
# 8354                           Asleep with One Eye Open   none
#
#                        authors           isbn  \
# 925               Marc Jampole              0
# 1658            Daniel Mangena     1999957113
# 3011             Marie Montine              0
# ...

# %% [markdown]
# 83 books with no year. Those could not be found in sidebar..

# %%
xd1 = df['year'].value_counts()
xd1
# Out:
# 2013    555
# 2012    552
# 2014    520
# 2011    433
# 2015    290
#        ...
# 1517      1
# 1726      1
# 1516      1
# 1766      1
# 1782      1
# Name: year, Length: 313, dtype: int64

# %% [markdown]
# ## Pages

# %%
xd = df['pages'].sort_values(ascending=True)
xd
# Out:
# 2490        0
# 6982        0
# 7433        0
# 7637        0
# 2727        0
#         ...
# 5449     4000
# 1075     4081
# 986      4211
# 2688     5216
# 7078    27500
# Name: pages, Length: 8139, dtype: int64

# %%
def select_pages()

# %%
#column "pages" (Later EDA: Replace 0 with mean)
#Replace 'None' 0, EDA: Fill later with mean 
#funct.fillup_mean('pages')
funct.replace_in_column(cleaningdata,'pages','None','0')
cleaningdata['pages'].value_counts()

# %% [markdown]
# ## Genres

# %%
#need to do explode on genres 
# if selected genres is in column/row/cells
def find_genres(genres):
    list=[]
    for i in genres:
        data = df[df['genres'].str.match(genres)]
    return data

# %% [markdown]
# ## Authors
